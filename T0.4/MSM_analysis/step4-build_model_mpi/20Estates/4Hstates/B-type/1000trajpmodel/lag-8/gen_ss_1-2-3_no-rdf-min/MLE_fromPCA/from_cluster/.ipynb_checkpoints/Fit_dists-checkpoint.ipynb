# %% [markdown]
# CG MSM from "primitive clustering" along rama-plot
# ====

# %%
import pyemma
pyemma.__version__
# Out:
# '2.1.1'

# %%
import os
# %pylab inline
matplotlib.rcParams.update({'font.size': 12})
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pyemma.coordinates as coor
import pyemma.msm as msm
import pyemma.plots as mplt
import msmbuilder
from msmbuilder.msm.ratematrix import ContinuousTimeMSM
import scipy
from msmtools.analysis.dense.decomposition import eigenvectors, eigenvalues
import operator
from scipy.optimize import curve_fit

# %% [markdown]
# Get the dists
# ------

# %%
Nproc = 16
Ntraj = 1000
Nmss = 2
msd_proc = np.load('msd_mss_trajs_all.npy')
wait_time_proc = np.load('wait_time_trajs_all.npy')
#for proc in range(Nproc):
#    trajs = np.split(np.arange(Nproc*(Ntraj/Nproc+1)),Nproc)[proc]
#    trajs = trajs[np.where(trajs<Ntraj)]
#    msd_proc.append( np.load('msd_mss_trajs_'+str(trajs[0])+'-'+str(trajs[-1])+'.npy') )
#    wait_time_proc.append( np.load('wait_time_trajs_'+str(trajs[0])+'-'+str(trajs[-1])+'.npy') )

# %%
msd = [[[] for x in range(Nmss)] for y in range(Nmss)]
for proc in range(Nproc):
    for imss in range(Nmss):
        for jmss in range(Nmss):
            for val in msd_proc[proc][imss][jmss]:
                msd[imss][jmss].append(val)

# %%
msd_hist = [[[] for x in range(Nmss)] for y in range(Nmss)]
msd_centers = [[[] for x in range(Nmss)] for y in range(Nmss)]
for imss in range(Nmss):
    for jmss in range(Nmss):
        msd_hist_tmp, msd_edges = np.histogram(msd[imss][jmss],bins=10,normed=1)
        msd_hist[imss][jmss] = msd_hist_tmp
        msd_centers[imss][jmss] = 0.5*(msd_edges[1:]+msd_edges[:-1])

# %%
for imss in range(Nmss):
    for jmss in range(Nmss):
        plt.plot(msd_centers[imss][jmss],msd_hist[imss][jmss])
        plt.show()

# %%
def exp_func(x, a, c, d):
    return a*np.exp(-c*x)+d

# %%
x_val = [[[] for x in range(Nmss)] for y in range(Nmss)]
y_val = [[[] for x in range(Nmss)] for y in range(Nmss)]
p0 = (1, 1, 1)
y_opt = [[[] for x in range(Nmss)] for y in range(Nmss)]
y_cov = [[[] for x in range(Nmss)] for y in range(Nmss)]
for imss in range(Nmss):
    for jmss in range(Nmss):
        x_val[imss][jmss].append( msd_centers[imss][jmss] )
        y_val[imss][jmss].append( msd_hist[imss][jmss] )
        tmp_opt, tmp_cov = curve_fit(exp_func, x_val[imss][jmss][0], y_val[imss][jmss][0], p0=p0)
        y_opt[imss][jmss].append( tmp_opt )
        y_cov[imss][jmss].append( tmp_cov )

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)
y_opt_vals = [[[] for x in range(Nmss)] for y in range(Nmss)]
for imss in range(Nmss):
    for jmss in range(Nmss):
        label = str(imss)+','+str(jmss)
        plt.plot(x_val[imss][jmss][0], y_val[imss][jmss][0],label=label,linewidth=3, color='k')
        y_opt_vals[imss][jmss].append( exp_func( x_val[imss][jmss][0], y_opt[imss][jmss][0][0], y_opt[imss][jmss][0][1], y_opt[imss][jmss][0][2] ) )
        plt.plot( x_val[imss][jmss][0], y_opt_vals[imss][jmss][0],label=label, linewidth=3, linestyle='--', color='r' )

plt.legend()
legend = plt.legend(fontsize='20',loc='upper center', bbox_to_anchor=(1.25, 1))
# frame = legend.get_frame()
# frame.set_linewidth('2.0')
# ltext = legend.get_texts()
# plt.setp(ltext, fontweight='bold')
# plt.xlim([-200,25000])
# plt.ylim([0,1.0])

# %%
y_val = np.array(y_val)
y_opt_vals = np.array(y_opt_vals)

# %%
y_opt_vals[0][0][0]
# Out:
# array([  4.60419944e+02,   3.73030492e+00,   1.80208760e-01,
#          1.52611938e-01,   1.52397413e-01,   1.52395745e-01,
#          1.52395732e-01,   1.52395732e-01,   1.52395732e-01,
#          1.52395732e-01])

# %%
ss_res = [[0. for x in range(Nmss)] for y in range(Nmss)]
ss_tot = [[0. for x in range(Nmss)] for y in range(Nmss)]
rsq = [[0. for x in range(Nmss)] for y in range(Nmss)]
for imss in range(Nmss):
    for jmss in range(Nmss):
        ss_res[imss][jmss] = np.sum( (y_val[imss][jmss][0]-y_opt_vals[imss][jmss][0])**2)
        ss_tot[imss][jmss] = numpy.sum(( np.subtract( y_val[imss][jmss][0], np.mean(y_val[imss][jmss][0])) )**2)
        rsq[imss][jmss] = 1. - ss_res[imss][jmss]/ss_tot[imss][jmss]

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)
plt.plot(np.concatenate(rsq),linewidth=3, color='k',marker='x',mew=10)
#plt.xticks(np.arange(len(rsq)),labels)
#plt.legend()
#legend = plt.legend(fontsize='20',loc='upper center', bbox_to_anchor=(1.25, 1))
# frame = legend.get_frame()
# frame.set_linewidth('2.0')
# ltext = legend.get_texts()
# plt.setp(ltext, fontweight='bold')
#plt.xlim([-200,25000])
#plt.ylim([0,1.0])

# %%
# repeat with the wait times

# %%
wt = [[] for x in range(Nmss)]
for proc in range(Nproc):
    for imss in range(Nmss):
        for val in wait_time_proc[proc][imss]:
            wt[imss].append(val)

# %%
wt_hist = [[] for x in range(Nmss)]
wt_centers = [[] for x in range(Nmss)]
for imss in range(Nmss):
    wt_hist_tmp, wt_edges = np.histogram(wt[imss],bins=10,normed=1)
    wt_hist[imss] = wt_hist_tmp
    wt_centers[imss] = 0.5*(wt_edges[1:]+wt_edges[:-1])

# %%
for imss in range(Nmss):
    plt.plot(wt_centers[imss],wt_hist[imss])
    plt.show()

# %%
x_val_wt = [[] for x in range(Nmss)]
y_val_wt = [[] for x in range(Nmss)]
y_opt_wt = [[] for x in range(Nmss)]
y_cov_wt = [[] for x in range(Nmss)]
p0 = (0.0001, 0.0001, 0.0001)
for imss in range(Nmss):
    x_val_wt[imss].append( wt_centers[imss][1:] )
    y_val_wt[imss].append( wt_hist[imss][1:] )
    tmp_opt, tmp_cov = curve_fit(exp_func, x_val_wt[imss][0], y_val_wt[imss][0],p0=p0)
    y_opt_wt[imss].append( tmp_opt )
    y_cov_wt[imss].append( tmp_cov )
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-35-c2299111407b> in <module>()
#       7     x_val_wt[imss].append( wt_centers[imss][1:] )
#       8     y_val_wt[imss].append( wt_hist[imss][1:] )
# ----> 9     tmp_opt, tmp_cov = curve_fit(exp_func, x_val_wt[imss][0], y_val_wt[imss][0],p0=p0)
#      10     y_opt_wt[imss].append( tmp_opt )
#      11     y_cov_wt[imss].append( tmp_cov )
#
# /home/theorie/rudzinski/soft/anaconda/envs/PyEmma-new/lib/python2.7/site-packages/scipy/optimize/minpack.pyc in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, **kwargs)
#     653         cost = np.sum(infodict['fvec'] ** 2)
#     654         if ier not in [1, 2, 3, 4]:
# --> 655             raise RuntimeError("Optimal parameters not found: " + errmsg)
#     656     else:
#     657         res = least_squares(func, p0, args=args, bounds=bounds, method=method,
#
# RuntimeError: Optimal parameters not found: Number of calls to function has reached maxfev = 800.

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)
y_opt_vals_wt = [[] for x in range(Nmss)]
for imss in range(Nmss):
    label = str(imss)
    plt.plot(x_val_wt[imss][0], y_val_wt[imss][0],label=label,linewidth=3, color='k')
    y_opt_vals_wt[imss].append( exp_func( x_val_wt[imss][0], y_opt_wt[imss][0][0], y_opt_wt[imss][0][1], y_opt_wt[imss][0][2] ) )
    plt.plot( x_val_wt[imss][0], y_opt_vals_wt[imss][0],label=label, linewidth=3, linestyle='--', color='r' )
    #p0_plot = exp_func( x_val_wt[imss][0], p0[0], p0[1], p0[2] )
    #plt.plot( x_val_wt[imss][0], p0_plot,label=label, linewidth=3, linestyle='--', color='b' )
    
plt.legend()
legend = plt.legend(fontsize='20',loc='upper center', bbox_to_anchor=(1.25, 1))
# frame = legend.get_frame()
# frame.set_linewidth('2.0')
# ltext = legend.get_texts()
# plt.setp(ltext, fontweight='bold')
# plt.xlim([-200,25000])
# plt.ylim([0,1.0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-36-a0b950c4f454> in <module>()
#       5     label = str(imss)
#       6     plt.plot(x_val_wt[imss][0], y_val_wt[imss][0],label=label,linewidth=3, color='k')
# ----> 7     y_opt_vals_wt[imss].append( exp_func( x_val_wt[imss][0], y_opt_wt[imss][0][0], y_opt_wt[imss][0][1], y_opt_wt[imss][0][2] ) )
#       8     plt.plot( x_val_wt[imss][0], y_opt_vals_wt[imss][0],label=label, linewidth=3, linestyle='--', color='r' )
#       9     #p0_plot = exp_func( x_val_wt[imss][0], p0[0], p0[1], p0[2] )
#
# IndexError: list index out of range

# %%
y_val_wt = np.array(y_val_wt)
y_opt_vals_wt = np.array(y_opt_vals_wt)

# %%
ss_res_wt = [0. for x in range(Nmss)]
ss_tot_wt = [0. for x in range(Nmss)]
rsq_wt = [0. for x in range(Nmss)]
for imss in range(Nmss):
    for jmss in range(Nmss):
        ss_res_wt[imss] = np.sum( (y_val_wt[imss][0]-y_opt_vals_wt[imss][0])**2)
        ss_tot_wt[imss] = numpy.sum(( np.subtract( y_val_wt[imss][0], np.mean(y_val_wt[imss][0])) )**2)
        rsq_wt[imss] = 1. - ss_res_wt[imss]/ss_tot_wt[imss]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-e5d3208534be> in <module>()
#       4 for imss in range(Nmss):
#       5     for jmss in range(Nmss):
# ----> 6         ss_res_wt[imss] = np.sum( (y_val_wt[imss][0]-y_opt_vals_wt[imss][0])**2)
#       7         ss_tot_wt[imss] = numpy.sum(( np.subtract( y_val_wt[imss][0], np.mean(y_val_wt[imss][0])) )**2)
#       8         rsq_wt[imss] = 1. - ss_res_wt[imss]/ss_tot_wt[imss]
#
# IndexError: list index out of range

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)
plt.plot(rsq_wt,linewidth=3, color='k',marker='x',mew=10)
ax.ticklabel_format(useOffset=False)
#plt.xticks(np.arange(len(rsq)),labels)
#plt.legend()
#legend = plt.legend(fontsize='20',loc='upper center', bbox_to_anchor=(1.25, 1))
# frame = legend.get_frame()
# frame.set_linewidth('2.0')
# ltext = legend.get_texts()
# plt.setp(ltext, fontweight='bold')
#plt.xlim([-200,25000])
#plt.ylim([0,1.0])

# %%
# try to calculate the diffusion constant
msd_avg = 0.5*( (1.0 / y_opt[0][1][0][1]) + (1.0 / y_opt[1][0][0][1]) )
print msd_avg
wt_avg = 0.5*( 1.0 / y_opt_wt[0][0][1] + 1.0 / y_opt_wt[1][0][1] )
print wt_avg
# Out:
# 0.0205218919649
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-40-448bcf33bef9> in <module>()
#       2 msd_avg = 0.5*( (1.0 / y_opt[0][1][0][1]) + (1.0 / y_opt[1][0][0][1]) )
#       3 print msd_avg
# ----> 4 wt_avg = 0.5*( 1.0 / y_opt_wt[0][0][1] + 1.0 / y_opt_wt[1][0][1] )
#       5 print wt_avg
#
# IndexError: list index out of range

# %%
D = msd_avg / (6*wt_avg)
D
# nm / sample
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-da1d1994b58b> in <module>()
# ----> 1 D = msd_avg / (6*wt_avg)
#       2 D
#       3 # nm / sample
#
# NameError: name 'wt_avg' is not defined

# %%
# what about directly from the data
msd_avg = 0.5*( np.mean(msd[0][1]) + np.mean(msd[1][0]) )
print msd_avg
wt_avg = 0.5*( np.mean(wt[0]) + np.mean(wt[1]) )
print wt_avg
# Out:
# 0.0295553689895
# 3629.50724638

# %%
D = msd_avg / (6*wt_avg)
D
# nm / sample
# Out:
# 1.3571800515065372e-06

# %%
# Now ts from MSM
mfpt_avg = 45.929199233304082*5*8
mfpt_avg
# Out:
# 1837.1679693321632

# %%
D_ts = msd_avg / (6*mfpt_avg)
D_ts
# nm / sample
# Out:
# 2.3634005544890033e-06

# %%
# cf direct from sim
D_sim = 0.004 * (10**(-5)) # cm^2/s
D_sim *= 10**2 # nm^2 / sample
D_sim
# Out:
# 2.067e-06

# %%
# what about the difference in waiting times?!
D_wt1 = (1.0 / y_opt[0][1][0][1]) / (6.0 / y_opt_wt[0][0][1])
D_wt1
# Out:
# 1.4837398498883206e-06

# %%
D_wt2 = (1.0 / y_opt[1][0][0][1]) / (6.0 / y_opt_wt[1][0][1])
D_wt2
# Out:
# 1.001102203114336e-06
